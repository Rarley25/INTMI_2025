# %% [markdown]
# <a href="https://colab.research.google.com/github/Rarley25/INTMI_2025/blob/main/Inform%C3%A1tica_28_10_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %%
num1 = (int(input("digite um número")))
if num1 > 0:
  print("Positivo")
elif num1 == 0:
  print("zero")
else:
  print ("Negativo")
# Out:
# digite um número-19
# Negativo

# %%
num = int(input("Digite numero: "))
if num %2 == 0:
  print("numero par")
else:
  print("Numero impar")
# Out:
# Digite numero: 25
# Numero impar

# %%
#Lista de exercicios do AVA
#1° Peça um número e informe se ele é maior que 10. Crie um algoritmo em Python para fazer essa verificação.
num1 = (int(input("Digite um numero")));
if num1 > 10:
  print("Maior que 10")
elif num1 == 10:
  print("Numero 10")
else:
  print("Menor que 10")
# Out:
# Digite um numero1
# Menor que 10

# %%
#2 Peça um número inteiro e informe se ele é par. Crie um algoritmo em Python que verifique se o número é divisível por 2.
num = (int(input("Digite um numero")))
if num %2 ==  0:
  print("Par")
else:
  print("Impar")

# %%
#3 Peça um nome e informe se ele contém a letra "a". Crie um algoritmo em Python que faça essa verificação.
Name = (str(input("Digite seu nome ")))
if "a" in Name:
  print("Contem a letra A")
else:
  print("Não há a letra A no nome")
# Out:
# Digite seu nome andre
# Contem a letra A

# %%
#4 Peça um número e informe se ele é múltiplo de 5. Crie um algoritmo em Python que verifique se o número é divisível por 5.
num = (int(input("Digite um numero")))
if num %5 == 0:
  print ("É divisivel por 5");
else:
  print("Não é divisivel por 5");
# Out:
# Digite um numero7
# Não é divisivel por 5

# %%
# 5 Peça a temperatura atual e informe se está quente (acima de 30°C) ou frio (30°C ou menos). Crie um algoritmo em Python para essa verificação.
temp = (int(input("Mê de a temperatura atual ")))
if temp >= 30:
  print("Quente")
else:
  print("Frio")
# Out:
# Mê de a temperatura atual 30
# Quente

# %%
# 6 Peça ao usuário para digitar "S" para continuar ou "N" para sair e informe a ação correspondente. Crie um algoritmo em Python que faça essa validação e exiba a mensagem correta.
num = (str(input("Digite 'S' para continuar e 'N' para sair")))
if "S" in num:
  print("Continuar")
elif "N" in num:
  print("Sair")
else:
  print("Invalido")
# Out:
# Digite 'S' para continuar e 'N' para sairS
# Continuar

# %%
# 7 Peça um número e informe se ele é negativo, zero ou positivo. Crie um algoritmo em Python para classificar o número.
num = (int(input("Digite um numero")));
if num >= 1:
  print("Positivo")
elif num == 0:
  print("Zero")
else:
  print("Negativo")
# Out:
# Digite um numero9
# Positivo

# %%
# 8 Peça um número de 1 a 7 e informe o dia da semana correspondente. Crie um algoritmo em Python que associe o número ao dia correto.
num = (int(input("digite um numero de um a 7")));
if num == 1:
  print("domingo")
elif num == 2:
  print("segunda")
elif num == 3:
  print("Terça")
elif num == 4:
  print("Quarta")
elif num == 5:
  print("Quinta")
elif num == 6:
  print("Sexta")
elif num == 7:
  print("Sabado")
# Out:
# digite um numero de um a 76
# Sexta

# %%
# 9 Peça um ano e informe se ele é bissexto. Crie um algoritmo em Python que verifique se o ano é divisível por 4 e não por 100, exceto se também for divisível por 400.
ano = (int(input("Digite um ano")))
if ano %4 == 0:
  print("Bissexto")
else:
  print("Não é bissexto")
# Out:
# Digite um ano2000
# Bissexto

# %%
# 10 Peça a quantidade de horas trabalhadas e o valor por hora. Se trabalhou até 40 horas, calcule o salário normalmente (horas × valor por hora). Se trabalhou mais de 40 horas, as horas extras devem ter um adicional de 50% (horas extras × valor por hora × 1.5). Crie um algoritmo em Python que realize esse cálculo corretamente.
hor = (int(input("Digite a quantidade de horas trabalhadas")))
val = (int(input("Digite o valor por hora"))
if hor <= 40:
  print(hor*val)
else:
  print(hor*val*1.5)
